# %%
import pandas as pd

# %%
data = pd.read_csv("./DATA/pakistanClean2.csv")
data.head()
# Out:
#         eventid  iyear  imonth  iday           provstate  \
# 0  200712030005   2007      12     3         Balochistan
# 1  200712040005   2007      12     4  Khyber Pakhtunkhwa
# 2  200712060008   2007      12     6         Balochistan
# 3  200712080003   2007      12     8         Balochistan
# 4  200712090002   2007      12     9         Balochistan
#
#                       city   latitude  longitude location  \
# 0  Qilla Abdullah district  30.803630  66.711752      NaN
# 1                 Peshawar  34.006004  71.537430      NaN
# 2               Dera Bugti  29.034412  69.158661      NaN
# 3                  Khuzdar  27.809921  66.620956      NaN
# 4                Nasirabad  28.458421  68.133223      NaN
#
#                                              summary  ...  addnotes  dbsource  \
# 0  12/03/2007: A bomb exploded in a madrassa in P...  ...       NaN     CETIS
# 1  12/04/2007: A female suicide bomber detonated ...  ...       NaN     CETIS
# ...

# %%
train_data = data[(data['TTP']==0) | (data['TTP'] ==1)]
train_data.to_csv('./DATA/pak_train_data.csv', index=False)
# Out:
# Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# NumExpr defaulting to 8 threads.

# %%
test_data = data[pd.isna(data['TTP'])].copy()
del test_data['TTP']
test_data.to_csv('./DATA/pak_test_data.csv', index=False)
